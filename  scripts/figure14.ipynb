# %%
# %matplotlib inline
import numpy as np
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
import matplotlib.pyplot as plt
plt.rcParams["font.family"] = "serif"
plt.rcParams.update({'mathtext.default':  'regular' })
FontSize=13
import pandas as pd

# %%
with open("../EWF/marconi.txt", "r") as file:
    marconi_ewf= [float(line.strip()) for line in file if line.strip()]
with open("../WUE/marconi.txt", "r") as file:
    marconi_wue= [float(line.strip()) for line in file if line.strip()]
    
with open("../EWF/fugaku.txt", "r") as file:
    fugaku_ewf= [float(line.strip()) for line in file if line.strip()]
with open("../WUE/fugaku.txt", "r") as file:
    fugaku_wue= [float(line.strip()) for line in file if line.strip()]
    
with open("../EWF/polaris.txt", "r") as file:
    polaris_ewf= [float(line.strip()) for line in file if line.strip()]
with open("../WUE/polaris.txt", "r") as file:
    polaris_wue= [float(line.strip()) for line in file if line.strip()]

with open("../EWF/frontier.txt", "r") as file:
    frontier_ewf= [float(line.strip()) for line in file if line.strip()]
with open("../WUE/frontier.txt", "r") as file:
    frontier_wue= [float(line.strip()) for line in file if line.strip()]

wi_marconi  =[]
wi_fugaku  =[]
wi_polaris  =[]
wi_frontier  =[]
wsi_direct = [0.29, 0.36, 0.4237, 0.2716]
wsi_indirect= [0.29, 0.36, 0.39303875326672477, 0.2801834775358028]
for i in range(0,len(fugaku_ewf)):
    wi_marconi.append(1.25*marconi_ewf[i]*(wsi_indirect[0]) + marconi_wue[i]*(wsi_direct[0]))
    wi_fugaku.append(1.4*fugaku_ewf[i]*(wsi_indirect[1]) + fugaku_wue[i]*(wsi_direct[1]))
    wi_polaris.append(1.65*polaris_ewf[i]*(wsi_indirect[2]) + polaris_wue[i]*(wsi_direct[2]))
    wi_frontier.append(1.05*frontier_ewf[i]*(wsi_indirect[3]) + frontier_wue[i]*(wsi_direct[3]))
    

sum_wi_marconi = sum(wi_marconi)    
sum_wi_fugaku = sum(wi_fugaku)
sum_wi_polaris = sum(wi_polaris)
sum_wi_frontier = sum(wi_frontier)

marconi = []
fugaku = []
polaris = []
frontier = []
for i in range(8760):
    marconi.append(2.6)
    fugaku.append(2.6)
    polaris.append(2.6)
    frontier.append(2.6)
    

wi_marconi_nuclear_tower = []
wi_fugaku_nuclear_tower = []
wi_polaris_nuclear_tower = []
wi_frontier_nuclear_tower = []
onsite_nuclear_tower = [0.29, 0.36, 0.4237, 0.2716]
offsite_nuclear_tower =[0.29, 0.36, 0.39303875326672477, 0.2801834775358028]
for i in range(0,len(fugaku)):
    wi_marconi_nuclear_tower.append(1.25*marconi[i]*(offsite_nuclear_tower[0]) + marconi_wue[i]*(onsite_nuclear_tower[0]))
    wi_fugaku_nuclear_tower.append(1.4*fugaku[i]*(offsite_nuclear_tower[1]) + fugaku_wue[i]*(onsite_nuclear_tower[1]))
    wi_polaris_nuclear_tower.append(1.65*polaris[i]*(offsite_nuclear_tower[2]) + polaris_wue[i]*(onsite_nuclear_tower[2]))
    wi_frontier_nuclear_tower.append(1.05*frontier[i]*(offsite_nuclear_tower[3]) + frontier_wue[i]*(onsite_nuclear_tower[3]))

sum_wi_marconi_nuclear_tower = sum(wi_marconi_nuclear_tower)
sum_wi_fugaku_nuclear_tower = sum(wi_fugaku_nuclear_tower)
sum_wi_polaris_nuclear_tower = sum(wi_polaris_nuclear_tower)
sum_wi_frontier_nuclear_tower = sum(wi_frontier_nuclear_tower)

    
    
marconi = []
fugaku = []
polaris = []
frontier = []
for i in range(8760):
    marconi.append(0.4)
    fugaku.append(0.4)
    polaris.append(0.4)
    frontier.append(0.4)
    
wi_marconi_nuclear_once = []
wi_fugaku_nuclear_once = []
wi_polaris_nuclear_once = []
wi_frontier_nuclear_once = []
onsite_nuclear_once = [0.29, 0.36, 0.4237, 0.2716]
offsite_nuclear_once = [0.29, 0.36, 0.39303875326672477, 0.2801834775358028]
for i in range(0,len(fugaku)):

    wi_marconi_nuclear_once.append(1.25*marconi[i]*(offsite_nuclear_once[0]) + marconi_wue[i]*(onsite_nuclear_once[0]))
    wi_fugaku_nuclear_once.append(1.4*fugaku[i]*(offsite_nuclear_once[1]) + fugaku_wue[i]*(onsite_nuclear_once[1]))
    wi_polaris_nuclear_once.append(1.65*polaris[i]*(offsite_nuclear_once[2]) + polaris_wue[i]*(onsite_nuclear_once[2]))
    wi_frontier_nuclear_once.append(1.05*frontier[i]*(offsite_nuclear_once[3]) + frontier_wue[i]*(onsite_nuclear_once[3]))   
#half hydro half nuclaer
sum_wi_marconi_nuclear_once = sum(wi_marconi_nuclear_once)
sum_wi_fugaku_nuclear_once = sum(wi_fugaku_nuclear_once)
sum_wi_polaris_nuclear_once = sum(wi_polaris_nuclear_once)
sum_wi_frontier_nuclear_once = sum(wi_frontier_nuclear_once)

marconi = []
fugaku = []
polaris = []
frontier = []
for i in range(8760):
    marconi.append(1.6)
    fugaku.append(1.6)
    polaris.append(1.6)
    frontier.append(1.6)
wi_marconi_coal = []    
wi_fugaku_coal = []
wi_polaris_coal = []
wi_frontier_coal = []
onsite_coal = [0.29, 0.36, 0.4237, 0.2716]
offsite_coal = [0.29, 0.36, 0.39303875326672477, 0.2801834775358028]
for i in range(0,len(fugaku)):
    wi_marconi_coal.append(1.25*marconi[i]*(offsite_coal[0]) + marconi_wue[i]*(onsite_coal[0]))
    wi_fugaku_coal.append(1.4*fugaku[i]*(offsite_coal[1]) + fugaku_wue[i]*(onsite_coal[1]))
    wi_polaris_coal.append(1.65*polaris[i]*(offsite_coal[2]) + polaris_wue[i]*(onsite_coal[2]))
    wi_frontier_coal.append(1.05*frontier[i]*(offsite_coal[3]) + frontier_wue[i]*(onsite_coal[3]))
sum_wi_marconi_coal = sum(wi_marconi_coal)
sum_wi_fugaku_coal = sum(wi_fugaku_coal)
sum_wi_polaris_coal = sum(wi_polaris_coal)
sum_wi_frontier_coal = sum(wi_frontier_coal)

cooling_tower_percentage = [(sum_wi_marconi_nuclear_tower-sum_wi_marconi)/sum_wi_marconi*100,
                            (sum_wi_fugaku_nuclear_tower-sum_wi_fugaku)/sum_wi_fugaku*100,
                            (sum_wi_polaris_nuclear_tower-sum_wi_polaris)/sum_wi_polaris*100,
                            (sum_wi_frontier_nuclear_tower-sum_wi_frontier)/sum_wi_frontier*100]
half_percentage = [(sum_wi_marconi_nuclear_once-sum_wi_marconi)/sum_wi_marconi*100,
                            (sum_wi_fugaku_nuclear_once-sum_wi_fugaku)/sum_wi_fugaku*100,
                            (sum_wi_polaris_nuclear_once-sum_wi_polaris)/sum_wi_polaris*100,
                            (sum_wi_frontier_nuclear_once-sum_wi_frontier)/sum_wi_frontier*100]
current_percentage = [(sum_wi_marconi_coal-sum_wi_marconi)/sum_wi_marconi*100,
                            (sum_wi_fugaku_coal-sum_wi_fugaku)/sum_wi_fugaku*100,
                            (sum_wi_polaris_coal-sum_wi_polaris)/sum_wi_polaris*100,
                            (sum_wi_frontier_coal-sum_wi_frontier)/sum_wi_frontier*100]

marconi = []
fugaku = []
polaris = []
frontier = []
for i in range(8760):
    marconi.append(8.47)
    fugaku.append(8.47)
    polaris.append(8.47)
    frontier.append(8.47)
    wi_marconi_coal = []    
wi_fugaku_3water = []
wi_polaris_3water= []
wi_frontier_3water = []
wi_marconi_3water = []
onsite_coal = [0.29, 0.36, 0.4237, 0.2716]
offsite_coal = [0.29, 0.36, 0.39303875326672477, 0.2801834775358028]
for i in range(0,len(fugaku)):
    wi_marconi_3water.append(1.25*marconi[i]*(offsite_coal[0]) + marconi_wue[i]*(onsite_coal[0]))
    wi_fugaku_3water.append(1.4*fugaku[i]*(offsite_coal[1]) + fugaku_wue[i]*(onsite_coal[1]))
    wi_polaris_3water.append(1.65*polaris[i]*(offsite_coal[2]) + polaris_wue[i]*(onsite_coal[2]))
    wi_frontier_3water.append(1.05*frontier[i]*(offsite_coal[3]) + frontier_wue[i]*(onsite_coal[3]))
sum_wi_marconi_3water= sum(wi_marconi_3water)
sum_wi_fugaku_3water = sum(wi_fugaku_3water)
sum_wi_polaris_3water = sum(wi_polaris_3water)
sum_wi_frontier_3water = sum(wi_frontier_3water)

water_percentage = [(sum_wi_marconi_3water-sum_wi_marconi)/sum_wi_marconi*100,
                            (sum_wi_fugaku_3water-sum_wi_fugaku)/sum_wi_fugaku*100,
                            (sum_wi_polaris_3water-sum_wi_polaris)/sum_wi_polaris*100,
                            (sum_wi_frontier_3water-sum_wi_frontier)/sum_wi_frontier*100]

water_percentage = [-i for i in water_percentage]
current_percentage = [-i for i in current_percentage]
half_percentage = [-i for i in half_percentage]
cooling_tower_percentage = [-i for i in cooling_tower_percentage]

# %%
fig, axs = plt.subplots(nrows=2, ncols=1, gridspec_kw={'hspace': 0.4, 'wspace': 0.2, 'bottom': 0.2, 
                    'top': 0.8, 'right':0.995, 'left':0.17}, figsize=(7.4,5.5),sharex=True)

with open("../CI/marconi.txt", "r") as file:
    ci_marconi= [float(line.strip()) for line in file if line.strip()]
with open("../CI/fugaku.txt", "r") as file:
    ci_fugaku= [float(line.strip()) for line in file if line.strip()]
with open("../CI/polaris.txt", "r") as file:
    ci_polaris= [float(line.strip()) for line in file if line.strip()]
with open("../CI/frontier.txt", "r") as file:
    ci_frontier= [float(line.strip()) for line in file if line.strip()]

marconi = np.mean(ci_marconi)
fugaku = np.mean(ci_fugaku)
polaris = np.mean(ci_polaris)
frontier = np.mean(ci_frontier)
barWidth = 0.2


current = [100*(marconi-1050)/marconi, 100*(fugaku-1050)/fugaku, 100*(polaris-1050)/polaris, 100*(frontier-1050)/frontier]
water_intense = [100*(marconi-20)/marconi, 100*(fugaku-20)/fugaku, 100*(polaris-20)/polaris, 100*(frontier-20)/frontier]
nuclear_100 = [100*(marconi-5)/marconi, 100*(fugaku-5)/fugaku, 100*(polaris-5)/polaris, 100*(frontier-5)/frontier]
renewable = [100*(marconi-96)/marconi, 100*(fugaku-96)/fugaku, 100*(polaris-96)/polaris, 100*(frontier-96)/frontier]
available_specs=[16, 32, 64, 128]
FontSize=13
pue=1.2
r1 = np.arange(4)
r2 = [x + barWidth for x in r1]
r3 = [x + 2*barWidth for x in r1]
r4 = [x + 3*barWidth for x in r1]

axs[0].grid(axis='y', linestyle='--')
axs[0].tick_params(axis='both', which='major', labelsize=FontSize)
axs[0].set_ylabel("Carbon Footprint \n(% saving w.r.t. \nCurrent Energy Mix)", fontsize=12.5,zorder=5)
axs[0].set_xticks([k+0.3 for k in range(4)])
axs[0].set_xticklabels(["Marconi", "Fugaku", "Polaris", "Frontier"], rotation=0, fontsize = FontSize) 
axs[0].set_ylim([-60,120])
axs[0].set_yticks([-60,0,60,120])
axs[0].bar(r1, current, width = barWidth, color = '#384D48', edgecolor = 'black',capsize=FontSize, label='100% Coal Usage',zorder=3)
axs[0].bar(r2,nuclear_100, width = barWidth, color = '#AF929D', edgecolor = 'black',capsize=FontSize, label='100% Nuclear Usage',zorder=3)
axs[0].bar(r3, renewable, width = barWidth, color ='lightgreen', edgecolor = 'black',capsize=FontSize, label='Other Renewable Energy Mix',zorder=3)
axs[0].bar(r4, water_intense, width = barWidth, color ='#4682B4', edgecolor = 'black',capsize=FontSize, label='Water-Intensive Renewable Energy Mix',zorder=3)

axs[0].text(0.15, -50, '-260', fontsize=13)
axs[0].text(1.15, -50, '-94', fontsize=13)
axs[0].text(2.15, -50, '-182', fontsize=13)
axs[0].text(3.15, -50, '-246', fontsize=13)

axs[1].text(0.63, 0.1, '-163', ha='center', va='center', transform=axs[1].transAxes, fontsize=FontSize)

axs[1].text(0.39,0.1,'-106', ha='center', va='center', transform=axs[1].transAxes, fontsize=FontSize)
axs[1].text(0.87, 0.1, '-71', ha='center', va='center', transform=axs[1].transAxes, fontsize=FontSize)

axs[1].tick_params(axis='both', which='major', labelsize=FontSize)
axs[1].set_ylabel("Water Footprint \n(% saving w.r.t. \nCurrent Energy Mix)", fontsize=12.5)
axs[1].set_xticks([k+0.25 for k in range(4)])
axs[1].set_xticklabels(["Marconi", "Fugaku", "Polaris", "Frontier"], rotation=0, fontsize = FontSize) 

axs[1].bar(r1, current_percentage, width = barWidth, color = '#384D48', edgecolor = 'black',capsize=FontSize, label='100% Coal Usage',zorder=3)
axs[1].bar(r2, cooling_tower_percentage, width = barWidth, color = '#AF929D', edgecolor = 'black',capsize=FontSize, label='100% Nuclear Usage',zorder=3)

axs[1].bar(r3, half_percentage, width = barWidth, color ='lightgreen', edgecolor = 'black',capsize=FontSize, label='Other Renewable Energy Mix',zorder=3)
axs[1].bar(r4, water_percentage, width = barWidth, color ='#4682B4', edgecolor = 'black',capsize=FontSize, label='Water-Intensive Renewable Energy Mix',zorder=3)
axs[1].set_ylim([-60, 60])
axs[1].set_yticks([-60,-20,20,60])
axs[1].legend(loc=(-0.05,2.5), frameon = False ,ncol=2,fontsize=12.5)
axs[1].grid(axis='y', linestyle='--')

plt.savefig("../figures/figure14.pdf",bbox_inches='tight')
